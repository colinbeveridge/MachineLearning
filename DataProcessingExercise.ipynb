# %%
import pandas as pd
import sklearn.model_selection as skmod
import datetime as dt

folder = 'Data/'
song_df = pd.read_csv(folder+'ml-03-data-processing-songs-dataset.csv')

song_df.shape
# Out:
# (1994, 16)

# %%
song_df.info()
song_df[song_df['Month'].isna()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1994 non-null   int64
#  1   Title                   1991 non-null   object
#  2   Artist                  1986 non-null   object
#  3   Top Genre               1986 non-null   object
#  4   Year                    1987 non-null   float64
#  5   Month                   1994 non-null   object
#  6   Beats Per Minute (BPM)  1985 non-null   float64
#  7   Energy                  1986 non-null   float64
#  8   Danceability            970 non-null    float64
#  9   Loudness (dB)           1987 non-null   float64
#  10  Liveness                1986 non-null   float64
#  11  Valence                 960 non-null    float64
#  12  Length (Duration)       1985 non-null   object
#  13  Acousticness            1986 non-null   float64
#  14  Speechiness             1990 non-null   float64
#  15  Popularity              1987 non-null   float64
# dtypes: float64(10), int64(1), object(5)
# memory usage: 210.4+ KB
# Empty DataFrame
# Columns: [Index, Title, Artist, Top Genre, Year, Month, Beats Per Minute (BPM), Energy, Danceability, Loudness (dB), Liveness, Valence, Length (Duration), Acousticness, Speechiness, Popularity]
# Index: []

# %%
song_df[song_df['Artist'].isna()]
# Out:
#       Index                                            Title Artist  \
# 664     665                      I Just Can't Help Believin'    NaN
# 775     776  Nothing Breaks Like a Heart (feat. Miley Cyrus)    NaN
# 886     887                          Starman - 2012 Remaster    NaN
# 1109   1110                                             Fire    NaN
# 1331   1332                                              NaN    NaN
# 1553   1554                     In Bloom - Nevermind Version    NaN
# 1775   1776                                 Freak On a Leash    NaN
# 1887   1888                                          Respect    NaN
#
#              Top Genre    Year Month  Beats Per Minute (BPM)  Energy  \
# 664    adult standards     NaN     7                     NaN     NaN
# 775                NaN  2018.0     3                   114.0    79.0
# 886                NaN     NaN     2                     NaN     NaN
# 1109         dance pop  1978.0     6                     NaN     NaN
# 1331               NaN  1985.0    11                     NaN    52.0
# 1553  alternative rock  1991.0     1                     NaN     NaN
# 1775               NaN     NaN    12                     NaN     NaN
# 1887               NaN     NaN     9                     NaN     NaN
#
#       Danceability  Loudness (dB)  Liveness  Valence Length (Duration)  \
# 664            NaN            NaN       9.0      NaN               274
# 775            NaN           -6.0       NaN      NaN               NaN
# 886            NaN            NaN      54.0      NaN               254
# 1109           NaN            NaN       NaN      NaN               NaN
# 1331           NaN          -11.0       NaN      NaN               NaN
# 1553           NaN           -5.0      21.0      NaN               NaN
# 1775           NaN           -6.0       NaN      NaN               256
# 1887           NaN           -5.0       5.0      NaN               NaN
#
#       Acousticness  Speechiness  Popularity
# 664            NaN          5.0         NaN
# 775            NaN          NaN         NaN
# 886           17.0          3.0        74.0
# 1109          20.0          3.0        56.0
# 1331           7.0          NaN        60.0
# 1553           NaN          NaN         NaN
# 1775           NaN          5.0        73.0
# 1887          16.0          4.0        73.0

# %%
# removing all rows with NaN title, artist because they also have more than 50% values missing
song_df = song_df[song_df['Title'].notnull()]
song_df = song_df[song_df['Artist'].notnull()]
song_df = song_df[song_df['Top Genre'].notnull()]

# drop danceability and valence columns because of missing values
song_df.drop(labels=['Danceability','Valence'],axis=1,inplace=True)


# also deleting Come on Eileen entry because it makes resulting data much cleaner
song_df = song_df[song_df['Title'] != 'Come On Eileen']
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1981 entries, 0 to 1993
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1981 non-null   int64
#  1   Title                   1981 non-null   object
#  2   Artist                  1981 non-null   object
#  3   Top Genre               1981 non-null   object
#  4   Year                    1981 non-null   float64
#  5   Month                   1981 non-null   object
#  6   Beats Per Minute (BPM)  1981 non-null   float64
#  7   Energy                  1981 non-null   float64
#  8   Loudness (dB)           1981 non-null   float64
#  9   Liveness                1981 non-null   float64
#  10  Length (Duration)       1981 non-null   object
#  11  Acousticness            1981 non-null   float64
#  12  Speechiness             1981 non-null   float64
#  13  Popularity              1981 non-null   float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 193.5+ KB

# %%
# write a function to convert months to numbers
def convertMonth(month):
    # check if already a number
    if month.isnumeric():
        # make int
        return int(month)
    # if not, convert
    else:
        if month == 'Jan':
            return 1
        elif month == 'Feb':
            return 2
        elif month == 'Mar':
            return 3
        elif month == 'Apr':
            return 4
        elif month == 'May':
            return 5
        elif month =='Jun':
            return 6
        elif month == 'Jul':
            return 7
        elif month == 'Aug':
            return 8
        elif month == 'Sep':
            return 9
        elif month == 'Oct':
            return 10
        elif month == 'Nov':
            return 11
        elif month == 'Dec':
            return 12
        else:
            return None

# write function to convert duration to int
def convertDuration(duration):
    if duration.isnumeric():
        return int(duration)
    else:
        duration = duration[0] + duration[2:]
        print(duration)
        return int(duration)


# get months to same format, convert year 92 to 1992
song_df.Month = song_df.Month.apply(convertMonth)
song_df['Year'] = song_df.Year.replace([92.],1992.)
song_df['Length (Duration)'] = song_df['Length (Duration)'].apply(convertDuration)
# Out:
# 1412
# 1121
# 1367
# 1292

# %%
# now that we are pretty clean, get descriptive statistics for all columns
colnames = song_df.columns[4:]
for col in colnames:
    std = song_df[col].std()
    mean = song_df[col].mean()
    outliers = song_df[(song_df[col] > mean + 3*std) | (song_df[col] < mean - 3*std)]
    print(col)
    print(f'Mean = {mean}')
    print(outliers[['Title',col]])
    print('============')
# Out:
# Year
# Mean = 1993.0085815244827
# Empty DataFrame
# Columns: [Title, Year]
# Index: []
# ============
# Month
# Mean = 6.521453811206461
# Empty DataFrame
# Columns: [Title, Month]
# Index: []
# ============
# Beats Per Minute (BPM)
# Mean = 120.23876829883898
#                                                 Title  Beats Per Minute (BPM)
# 133                                               Zij                    18.0
# 284        Lady Jane - (Original Single Mono Version)                   305.0
# 1901  Lucy In The Sky With Diamonds - Remastered 2009                    15.0
# 1977                          Appleknockers Flophouse                   297.0
# ============
# Energy
# Mean = 59.641090358404846
# Empty DataFrame
# Columns: [Title, Energy]
# Index: []
# ============
# Loudness (dB)
# Mean = -9.018172640080767
#                                                   Title  Loudness (dB)
# 527                                          I See Fire          -21.0
# 690                    Het het nog nooit zo donker west          -20.0
# 878                                Famous Blue Raincoat          -22.0
# 971                                           Landslide          -22.0
# 1049                                      Stayin' Alive          -20.0
# 1208                             Private Investigations          -20.0
# 1256                            Theme from Harry's Game          -24.0
# 1302                                        Nightporter          -20.0
# 1330                                          Why Worry          -21.0
# 1339                           Moon Over Bourbon Street          -22.0
# 1349                        Sometimes It Snows in April          -24.0
# 1370                                               Anne          -27.0
# 1373  Fire - Live at the Winterland, San Francisco, ...          -21.0
# 1392                                            Fragile          -21.0
# 1406                                   Liefde Van Later          -22.0
# 1413                                            Suzanne          -21.0
# 1833                                Blowin' in the Wind          -21.0
# 1875                           When a Man Loves a Woman          -20.0
# 1931            What A Wonderful World - Single Version          -21.0
# 1961                          Albatross - 2018 Remaster          -22.0
# 1978                The First Time Ever I Saw Your Face          -22.0
# 1988                                         Summertime          -21.0
# ============
# Liveness
# Mean = 19.009086320040385
#                                                   Title  Liveness
# 13                                       I'm going home      81.0
# 46                                           Sweet Jane      70.0
# 94                                       Limburg - Live      93.0
# 128                                        De wedstrijd      79.0
# 159                                    It's Raining Men      70.0
# 163   Zing - Vecht - Huil - Bid - Lach - Werk En Bew...      97.0
# 173   Free Fallin' - Live at the Nokia Theatre, Los ...      70.0
# 186                                    Go With The Flow      83.0
# 244                                       So Incredible      72.0
# 258                             Live And Let Die - Live      97.0
# 320                                   Geef Mij Je Angst      97.0
# 341                                     You Oughta Know      87.0
# 352                                         In Nije Dei      96.0
# 400                                  Mag Ik Dan Bij Jou      71.0
# 405                                      Wonderful Days      99.0
# 411                                    Peter Gunn Theme      92.0
# 440                              A Boy Named Sue (Live)      78.0
# 492                                           Droomland      95.0
# 493                                    Wat Zou Je Doen?      71.0
# 498                                         San Quentin      90.0
# 504                                            Dodenrit      81.0
# 580                                           Zandloper      95.0
# 606                                              Psycho      87.0
# 610                    Zeg Maar Niets Meer - Remastered      91.0
# 684                                            Thriller      85.0
# 712                                             Holiday      89.0
# 759                         Always Remember Us This Way      76.0
# 790                         About A Girl - Live Version      73.0
# 890                                         Lola - Live      72.0
# 955                                         Love Is All      85.0
# 968   No Woman, No Cry - Live At The Lyceum, London/...      73.0
# 990                                  Nights On Broadway      86.0
# 1001                                      Dancing Queen      76.0
# 1056                                      The Passenger      73.0
# 1077                                      Isn't It Time      82.0
# 1082                       Don't Stop Me Now - 2011 Mix      77.0
# 1099   Stir It Up - Live At The Pavillon De Paris, 1977      97.0
# 1146  More Than A Woman - From "Saturday Night Fever...      85.0
# 1258                                      Gloria - Live      99.0
# 1274      Pride (In The Name Of Love) - Remastered 2009      78.0
# 1373  Fire - Live at the Winterland, San Francisco, ...      98.0
# 1400                               I Will Follow - Live      96.0
# 1438                  Tonight (With David Bowie) - Live      93.0
# 1495                                         Love Shack      85.0
# 1572  Layla - Acoustic; Live at MTV Unplugged, Bray ...      94.0
# 1591                            Vlieg Met Me Mee - Live      77.0
# 1653                                              Polly      91.0
# 1686                                An American Trilogy      96.0
# 1712                 Casser la voix - Live "Si Ce Soir"      84.0
# 1753                                   Somebody to Love      97.0
# 1779                  Killer / Papa Was a Rollin' Stone      76.0
# 1789                                     Ik Heb Je Lief      73.0
# 1885                A Day In The Life - Remastered 2009      92.0
# 1900  Sgt. Pepper's Lonely Hearts Club Band - Remast...      80.0
# 1934             Ain't Got No - I Got Life - Remastered      76.0
# 1982                                          Get Ready      83.0
# 1990                                          Hound Dog      76.0
# ============
# Length (Duration)
# Mean = 262.6208985360929
#                                                   Title  Length (Duration)
# 13                                       I'm going home                639
# 40                        Don't Let Me Be Misunderstood                629
# 151                                    Ghost Love Score                602
# 490                                       Tubular Bells                809
# 647                                   Cold Little Heart                598
# 670                                           Blackstar                598
# 707                                 Thinking Of A Place                671
# 799                                       Child in Time                620
# 818                    I Heard It Through The Grapevine                663
# 842                                              Echoes               1412
# 880                Yours Is No Disgrace - 2003 Remaster                581
# 904   Close to the Edge (i. The Solid Time of Change...               1121
# 916                                           Free Bird                559
# 923                     Firth of Fifth - New Stereo Mix                575
# 951                            Autobahn - 2009 Remaster               1367
# 965               Shine On You Crazy Diamond (Pts. 1-5)                811
# 977                                          Jungleland                576
# 994                             Sex Machine - Pt. 1 & 2                715
# 1034                                    Fool's Overture                653
# 1043                                    Bat Out of Hell                590
# 1166                        The Turn of a Friendly Card                966
# 1205                                     Telegraph Road                859
# 1446                                           Musica è                659
# 1536                                          Estranged                564
# 1884                                            The End                703
# 1982                                          Get Ready               1292
# ============
# Acousticness
# Mean = 28.933871781928318
# Empty DataFrame
# Columns: [Title, Acousticness]
# Index: []
# ============
# Speechiness
# Mean = 4.992428066633013
#                                          Title  Speechiness
# 73                              The Wild Rover         25.0
# 114   Lose Yourself - From "8 Mile" Soundtrack         26.0
# 120           Single Ladies (Put a Ring on It)         30.0
# 125                Crazy In Love (feat. Jay-Z)         23.0
# 175                                  Hollereer         24.0
# 190                                  Nederwiet         19.0
# 219                                       Stan         24.0
# 238                         Where Is The Love?         20.0
# 264                       Empire State Of Mind         39.0
# 282                               Watskeburt?!         23.0
# 366                     When The Sun Goes Down         20.0
# 424                                   Man Down         19.0
# 465                            Ni**as In Paris         32.0
# 523                                 Formidable         19.0
# 580                                  Zandloper         24.0
# 644                              Love Yourself         44.0
# 689                                      Human         30.0
# 704                                  Amsterdam         24.0
# 714                           Rapper's Delight         25.0
# 724                                       Skin         31.0
# 728                              Duurt Te Lang         20.0
# 763                                 Youngblood         46.0
# 786                                    bad guy         38.0
# 864                              Mercedes Benz         55.0
# 920                  La Grange - 2005 Remaster         22.0
# 1022            Blitzkrieg Bop - 2016 Remaster         23.0
# 1066      One Love / People Get Ready - Medley         32.0
# 1086                                   Roxanne         36.0
# 1164                                     Think         19.0
# 1264                           Buffalo Soldier         31.0
# 1361              One Vision - Remastered 2011         26.0
# 1462                    Sympathy For The Devil         28.0
# 1567                       Killing In The Name         30.0
# 1591                   Vlieg Met Me Mee - Live         20.0
# 1652                                   Annabel         30.0
# 1711                                No Diggity         29.0
# 1748                    Can't Stand Losing You         31.0
# 1786                                        As         19.0
# 1818                          The Next Episode         27.0
# 1824                                My Name Is         32.0
# 1935              Voodoo Child (Slight Return)         39.0
# 1951          Whole Lotta Love - 1990 Remaster         41.0
# ============
# Popularity
# Mean = 59.499242806663304
#                         Title  Popularity
# 24        Dichterbij Dan Ooit        16.0
# 411          Peter Gunn Theme        14.0
# 605           Het Dorp - Live        15.0
# 624       Three Days In A Row        13.0
# 626            R U Kiddin' Me        16.0
# 752   Banger Hart - Radio Mix        16.0
# 753               Malle Babbe        15.0
# 773          Hou Vol Hou Vast        12.0
# 1793                Sacrifice        11.0
# ============

# %%
# convert month and year into datetime

song_df['Day'] = 1
song_df['Full Date'] = pd.to_datetime(song_df[['Year','Month','Day']])
today = dt.date.today()
song_df['Age'] = None


for idx,date in enumerate(song_df['Full Date']):
    age = (dt.datetime.today() - date).days
    song_df['Age'].iloc[idx] = age

song_df['Age']
song_df.drop(['Full Date','Day','Month','Year'],axis=1,inplace=True)
song_df.info()
song_df.columns
# age is now calculated and other date columns dropped
# Out:
# C:\Users\cbevr\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1981 entries, 0 to 1993
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1981 non-null   int64
#  1   Title                   1981 non-null   object
#  2   Artist                  1981 non-null   object
#  3   Top Genre               1981 non-null   object
#  4   Beats Per Minute (BPM)  1981 non-null   float64
#  5   Energy                  1981 non-null   float64
#  6   Loudness (dB)           1981 non-null   float64
#  7   Liveness                1981 non-null   float64
#  8   Length (Duration)       1981 non-null   int64
#  9   Acousticness            1981 non-null   float64
#  10  Speechiness             1981 non-null   float64
#  11  Popularity              1981 non-null   float64
#  12  Age                     1981 non-null   object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 185.7+ KB
# Index(['Index', 'Title', 'Artist', 'Top Genre', 'Beats Per Minute (BPM)',
#        'Energy', 'Loudness (dB)', 'Liveness', 'Length (Duration)',
#        'Acousticness', 'Speechiness', 'Popularity', 'Age'],
#       dtype='object')

# %%
# now run get dummies on top genre
song_df = pd.get_dummies(song_df,columns=['Top Genre'])
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1981 entries, 0 to 1993
# Columns: 161 entries, Index to Top Genre_yacht rock
# dtypes: float64(7), int64(2), object(3), uint8(149)
# memory usage: 466.2+ KB

# %% [markdown]
# END OF PROCESSING/CLEANING EXERCISE: BEGIN MODEL TRAINING EXERCISE

# %%
X = song_df
y = song_df['Popularity']
X.drop('Popularity',axis=1,inplace=True)

X_train, X_test, y_train, y_test = skmod.train_test_split(X,y,test_size=0.3,random_state=26)

X_train.describe()
# Out:
#              Index  Beats Per Minute (BPM)       Energy  Loudness (dB)  \
# count  1386.000000             1386.000000  1386.000000    1386.000000
# mean    985.055556              119.993506    59.756854      -8.953824
# std     576.889223               28.365140    22.050992       3.632688
# min       1.000000               37.000000     3.000000     -27.000000
# 25%     484.250000               99.000000    43.000000     -11.000000
# 50%     978.500000              119.000000    61.500000      -8.000000
# 75%    1475.750000              136.000000    77.000000      -6.000000
# max    1994.000000              305.000000   100.000000      -2.000000
#
#           Liveness  Length (Duration)  Acousticness  Speechiness  \
# count  1386.000000        1386.000000   1386.000000  1386.000000
# mean     19.134921         260.805195     29.189755     5.018038
# std      17.009994          86.237634     28.977884     4.536777
# min       2.000000          93.000000      0.000000     2.000000
# 25%       9.000000         212.000000      4.000000     3.000000
# 50%      12.000000         245.000000     18.000000     4.000000
# 75%      23.000000         289.000000     50.000000     5.000000
# max      99.000000        1367.000000     99.000000    55.000000
#
#        Top Genre_acid jazz  Top Genre_acoustic pop  ...  Top Genre_reggae  \
# count          1386.000000             1386.000000  ...       1386.000000
# mean              0.000722                0.000722  ...          0.003608
# std               0.026861                0.026861  ...          0.059976
# min               0.000000                0.000000  ...          0.000000
# 25%               0.000000                0.000000  ...          0.000000
# 50%               0.000000                0.000000  ...          0.000000
# 75%               0.000000                0.000000  ...          0.000000
# max               1.000000                1.000000  ...          1.000000
#
#        Top Genre_reggae fusion  Top Genre_rock-and-roll  \
# count              1386.000000              1386.000000
# mean                  0.002165                 0.000722
# std                   0.046491                 0.026861
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   1.000000                 1.000000
#
#        Top Genre_scottish singer-songwriter  Top Genre_soft rock  \
# count                           1386.000000               1386.0
# mean                               0.001443                  0.0
# std                                0.037973                  0.0
# min                                0.000000                  0.0
# 25%                                0.000000                  0.0
# 50%                                0.000000                  0.0
# 75%                                0.000000                  0.0
# max                                1.000000                  0.0
#
#        Top Genre_stomp and holler  Top Genre_streektaal  Top Genre_trance  \
# count                 1386.000000                1386.0       1386.000000
# mean                     0.000722                   0.0          0.000722
# std                      0.026861                   0.0          0.026861
# min                      0.000000                   0.0          0.000000
# 25%                      0.000000                   0.0          0.000000
# 50%                      0.000000                   0.0          0.000000
# 75%                      0.000000                   0.0          0.000000
# max                      1.000000                   0.0          1.000000
#
#        Top Genre_uk pop  Top Genre_yacht rock
# count       1386.000000           1386.000000
# mean           0.000722              0.000722
# std            0.026861              0.026861
# min            0.000000              0.000000
# 25%            0.000000              0.000000
# 50%            0.000000              0.000000
# 75%            0.000000              0.000000
# max            1.000000              1.000000
#
# [8 rows x 157 columns]

# %% [markdown]
# END OF MODEL TRAINING EXERCISE
